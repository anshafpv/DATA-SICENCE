# %% [markdown]
# <a href="https://colab.research.google.com/github/anshafpv/DATA-SICENCE/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data={
    "product":["laptop","phone","tablet","laptop","phone","tablet"],
    "sales":[50,80,40,70,90,60],
    "price":[50000,30000,20000,55000,32000,22000],
    "month":["jan","jan","feb","feb","mar","mar"]
}
sns.barplot(x="product",y="sales",data=data)                # 1. barplot
plt.show()                                      # compare sales of different products

# %%
sns.histplot(x="sales",data=data)
plt.show()
